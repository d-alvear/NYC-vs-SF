# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import json
import folium
from folium import plugins
import geopandas as gpd

# %%
#bring in data
nyc_data = gpd.read_file('nyc-merged.geojson')
nyc_data.drop(['id'], axis=1, inplace=True)

sf_data = gpd.read_file('sf-data-test.geojson')
sf_data.drop(['id'], axis=1, inplace=True)

nyc_rent = pd.read_csv('nyc-rent.csv', delimiter='\t')

# %%
nyc_data.head()
# Out:
#                  Name      City  Median_Rent  \
# 0    Roosevelt Island  New York       3986.0
# 1  Washington Heights  New York       2589.0
# 2           Chinatown  New York       3742.0
# 3   Greenwich Village  New York       4374.0
# 4              Inwood  New York       2446.0
#
#                                             geometry
# 0  POLYGON ((-73.96143117599991 40.74851331600007...
# 1  POLYGON ((-73.92192594599993 40.85516011100009...
# 2  POLYGON ((-73.99300676872572 40.71433187712174...
# 3  POLYGON ((-73.98733999497614 40.73372011284643...
# 4  POLYGON ((-73.92550434099991 40.87713683500004...

# %%
nyc_data.rename(columns={'Name':'Neighborhood','geometry':'Geometry'}, inplace=True)

# %%
nyc_data.loc[12,'Median_Rent'] = float(5344)
nyc_data.loc[24,'Median_Rent'] = float(4084)
nyc_data.loc[33,'Median_Rent'] = float(3627)
nyc_data.loc[34,'Median_Rent'] = float(4924)

# %%
with open('nyc-merged.geojson', 'w') as f:
    f.write(nyc_data.to_json())

# %%
state_geo = f'nyc-merged.geojson'
state_data = nyc_data

bins = list(nyc_data['Median_Rent'].quantile([0, 0.25, 0.5, 0.75, 1]))

m = folium.Map(location=[40.7831, -73.9712], zoom_start=12)

choropleth = folium.Choropleth(
    geo_data=state_geo,
    name='choropleth',
    data=nyc_data,
    columns=['Neighborhood', 'Median_Rent'],
    key_on='feature.properties.Name',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    nan_fill_color='grey',
    nan_fill_opacity=0.4,
    bins=bins,
    highlight=True,
    legend_name='Median Rent'
    
).add_to(m)

folium.LayerControl().add_to(m)

choropleth.geojson.add_child(
    folium.features.GeoJsonTooltip(['Name', 'Median_Rent'], aliases=['Neighborhood', 'Median Rent'])
)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
sf_data.head()
# Out:
#              Neighborhood           City  Zillow Median  \
# 0                Seacliff  San Francisco         4911.0
# 1             Lake Street  San Francisco         4345.0
# 2  Presidio National Park  San Francisco         3784.0
# 3        Presidio Terrace           None         5839.0
# 4          Inner Richmond  San Francisco         4284.0
#
#                                             geometry
# 0  (POLYGON ((-122.4934552679999 37.7835181710000...
# 1  (POLYGON ((-122.4871507149999 37.7837854270000...
# 2  (POLYGON ((-122.4775801709999 37.8109931130000...
# 3  (POLYGON ((-122.4724105299999 37.7873465390000...
# 4  (POLYGON ((-122.4726257899999 37.7863148060000...

# %%
sf_data.rename(columns={'Zillow Median':'Median_Rent','geometry':'Geometry'}, inplace=True)

# %%
state_geo = f'sf-data-test.geojson'
state_data = sf_data

bins = list(sf_data['Median_Rent'].quantile([0, 0.25, 0.5, 0.75, 1]))

m = folium.Map(location=[37.7749, -122.4194], zoom_start=12)

choropleth = folium.Choropleth(
    geo_data=state_geo,
    name='choropleth',
    data=sf_data,
    columns=['Neighborhood', 'Median_Rent'],
    key_on='feature.properties.Neighborhood',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    nan_fill_color='grey',
    nan_fill_opacity=0.4,
    bins=bins,
    highlight=True,
    legend_name='Median Rent'
    
).add_to(m)

folium.LayerControl().add_to(m)

choropleth.geojson.add_child(
    folium.features.GeoJsonTooltip(['Neighborhood', 'Zillow Median'], aliases=['Neighborhood', 'Median Rent'])
)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
with open('nyc-merged.geojson', 'w') as f:
    f.write(nyc_data.to_json())

# %% [markdown]
# ### To Do:
#
# * ~~name column/field names uniform~~
# * binary classification to set local and overall categories
# * add columns with classifications
# * export geojsons with new names & columns
